# %%
import ee
ee.Authenticate()
ee.Initialize(project="earthpulse-472111")  # replace with your project ID
# Out:
# *** Earth Engine *** Share your feedback by taking our Annual Developer Satisfaction Survey: https://google.qualtrics.com/jfe/form/SV_7TDKVSyKvBdmMqW?ref=4i2o6

# %%
import ee

# Initialize with your project again (safest)
ee.Initialize(project="earthpulse-472111")

# Print info about Sentinel-2 dataset
s2_info = ee.ImageCollection("COPERNICUS/S2_SR_HARMONIZED") \
    .first() \
    .getInfo()

print("Successfully connected to Earth Engine!")
print("Example Sentinel-2 Image ID:", s2_info["id"])
# Out:
# Successfully connected to Earth Engine!
# Example Sentinel-2 Image ID: COPERNICUS/S2_SR_HARMONIZED/20150711T165456_20150711T165450_T15RXN

# %%
import ee
import geemap
import matplotlib.pyplot as plt

ee.Initialize(project="earthpulse-472111")
